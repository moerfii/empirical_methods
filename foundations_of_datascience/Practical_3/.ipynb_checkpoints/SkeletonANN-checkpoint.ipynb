# %% [markdown]
# # Practical 3: Artificial Neural Network
#
# This is the first task of Practical 3. You will build a neural network to classify the handwritten digits from the MNIST dataset (http://yann.lecun.com/exdb/mnist/).
# You will build the classifier from scartch.
#
# We will mark your code based on the accuracy of your model. You should get **at least 97%** accuracy on this dataset. Don't forget to save and check in your model.

# %% [markdown]
# ## Import the libraries

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

import tensorflow as tf
from tensorflow import keras

# Tensorboard
# %load_ext tensorboard
import tensorboard

# Scikit
from sklearn.model_selection import RandomizedSearchCV

# %%
tf.__version__
# Out:
# '1.14.0'

# %%
tf.keras.__version__
# Out:
# '2.2.4-tf'

# %% [markdown]
# ## Prepare the dataset
#
# In this block, you will prepare the data for the training, such as normalisation.

# %%
from keras.datasets import mnist
(X_train_full, y_train_full), (X_test, y_test) = mnist.load_data()

for i in range(0,9):
    plt.subplot(330 + 1 + i)
    plt.imshow(X_train_full[i])
plt.show()

X_train_full.shape
# Out:
# (60000, 28, 28)

# %%
# 1H
y_train_full = keras.utils.to_categorical(y_train_full, num_classes=10)
y_test = keras.utils.to_categorical(y_test, num_classes=10)

# %%
# Validation Data & Normalisation
np.random.seed(1154)
validation_size = 12000 # 80%
shuffled_indices = np.random.permutation(X_train_full.shape[0])
X_valid, X_train = X_train_full[shuffled_indices[:validation_size]], X_train_full[shuffled_indices[validation_size:]]
y_valid, y_train = y_train_full[shuffled_indices[:validation_size]], y_train_full[shuffled_indices[validation_size:]]

X_train = (X_train - np.mean(X_train))/np.std(X_train)
X_valid = (X_valid - np.mean(X_valid))/np.std(X_valid)
X_test = (X_test - np.mean(X_test))/np.std(X_test)

# %% [markdown]
# ## Build and train the model
#
# Build and train your model.

# %%
## Setup Leaky
#def leaky_relu(X):
#    return tf.nn.leaky_relu(X, alpha=0.001)

# Model
model = keras.models.Sequential()
model.add(keras.layers.Flatten(input_shape=[28, 28]))
model.add(keras.layers.Dense(1000, activation="relu"))
#model.add(keras.layers.Dense(100, activation="relu"))
#model.add(keras.layers.Dense(100, activation="relu"))
#model.add(keras.layers.Dense(10, activation="relu"))
#model.add(keras.layers.Dropout(rate=0.2))
model.add(keras.layers.Dense(10, activation="softmax"))

# %%
## Hyper Model
#def build_model(n_hidden=1, n_neurons=30, learning_rate=0.001, input_shape=[28,28]):
#    model = keras.models.Sequential()
#    model.add(keras.layers.InputLayer(input_shape=input_shape))
#    for layer in range(n_hidden):
#        model.add(keras.layers.Dense(n_neurons, activation="relu"))
#    model.add(keras.layers.Dense(10))
#    optimizer = keras.optimizers.Adam(learning_rate=learning_rate)
#    model.compile(loss="categorical_crossentropy", optimizer=optimizer)
#    return model

# %%
##Transfer
#keras_reg = keras.wrappers.scikit_learn.KerasRegressor(build_model)

# %%
#param_distributions = {
#    "n_hidden": [0, 1, 2, 3],
#    "n_neurons": np.arange(1, 100).tolist(),
#    "learning_rate": [0.0001, 0.001, 0.01]
#}

# %%
#rnd_search_cv = RandomizedSearchCV(
#                        estimator=keras_reg,
#                        param_distributions=param_distributions,
#                        n_iter=100,
#                        cv=3
#)
#
#rnd_search_cv.fit(X_train_full, y_train_full, epochs=1)

# %%
#rnd_search_cv.best_params_

# %%
# Loss & History
model.compile(loss="categorical_crossentropy",
              optimizer=keras.optimizers.Adam(lr=0.001),
              metrics=["accuracy"])

early_stopping_cb = keras.callbacks.EarlyStopping(patience=10, restore_best_weights=True)
history = model.fit(X_train, y_train, batch_size=256, epochs=32, validation_data=(X_valid, y_valid),
                   callbacks=[keras.callbacks.TensorBoard(log_dir="logs/fit/"), early_stopping_cb])
# Out:
# Epoch 1/32
#   2/188 [..............................] - ETA: 3:05 - loss: 2.1404 - accuracy: 0.2559WARNING:tensorflow:Callbacks method `on_train_batch_end` is slow compared to the batch time (batch time: 0.0299s vs `on_train_batch_end` time: 1.9679s). Check your callbacks.
# 188/188 [==============================] - 8s 43ms/step - loss: 0.2566 - accuracy: 0.9213 - val_loss: 0.1438 - val_accuracy: 0.9567
# Epoch 2/32
# 188/188 [==============================] - 6s 30ms/step - loss: 0.0962 - accuracy: 0.9716 - val_loss: 0.1121 - val_accuracy: 0.9671
# Epoch 3/32
# 188/188 [==============================] - 5s 29ms/step - loss: 0.0569 - accuracy: 0.9831 - val_loss: 0.0944 - val_accuracy: 0.9703
# Epoch 4/32
# 188/188 [==============================] - 6s 29ms/step - loss: 0.0380 - accuracy: 0.9891 - val_loss: 0.0968 - val_accuracy: 0.9709
# Epoch 5/32
# 188/188 [==============================] - 6s 31ms/step - loss: 0.0264 - accuracy: 0.9927 - val_loss: 0.0843 - val_accuracy: 0.9742
# Epoch 6/32
# 188/188 [==============================] - 5s 29ms/step - loss: 0.0173 - accuracy: 0.9953 - val_loss: 0.0839 - val_accuracy: 0.9761
# Epoch 7/32
# 188/188 [==============================] - 5s 29ms/step - loss: 0.0125 - accuracy: 0.9966 - val_loss: 0.0752 - val_accuracy: 0.9773
# Epoch 8/32
# 188/188 [==============================] - 8s 44ms/step - loss: 0.0075 - accuracy: 0.9987 - val_loss: 0.0788 - val_accuracy: 0.9786
# Epoch 9/32
# 188/188 [==============================] - 5s 26ms/step - loss: 0.0045 - accuracy: 0.9993 - val_loss: 0.0844 - val_accuracy: 0.9774
# Epoch 10/32
# 188/188 [==============================] - 5s 26ms/step - loss: 0.0047 - accuracy: 0.9990 - val_loss: 0.0865 - val_accuracy: 0.9783
# Epoch 11/32
# 188/188 [==============================] - 5s 29ms/step - loss: 0.0040 - accuracy: 0.9993 - val_loss: 0.0868 - val_accuracy: 0.9787
# Epoch 12/32
# 188/188 [==============================] - 5s 26ms/step - loss: 0.0077 - accuracy: 0.9980 - val_loss: 0.1074 - val_accuracy: 0.9741
# Epoch 13/32
# 188/188 [==============================] - 5s 25ms/step - loss: 0.0241 - accuracy: 0.9918 - val_loss: 0.1009 - val_accuracy: 0.9745
# Epoch 14/32
# 188/188 [==============================] - 6s 33ms/step - loss: 0.0185 - accuracy: 0.9937 - val_loss: 0.1067 - val_accuracy: 0.9771
# Epoch 15/32
# 188/188 [==============================] - 5s 26ms/step - loss: 0.0086 - accuracy: 0.9971 - val_loss: 0.1014 - val_accuracy: 0.9772
# Epoch 16/32
# 188/188 [==============================] - 5s 27ms/step - loss: 0.0050 - accuracy: 0.9984 - val_loss: 0.1097 - val_accuracy: 0.9777
# Epoch 17/32
# 188/188 [==============================] - 5s 26ms/step - loss: 0.0071 - accuracy: 0.9977 - val_loss: 0.1017 - val_accuracy: 0.9767

# %%
# show the structure of your model
model.summary()
# Out:
# Model: "sequential_338"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# flatten_8 (Flatten)          (None, 784)               0
# _________________________________________________________________
# dense_845 (Dense)            (None, 1000)              785000
# _________________________________________________________________
# dense_846 (Dense)            (None, 10)                10010
# =================================================================
# Total params: 795,010
# Trainable params: 795,010
# Non-trainable params: 0
# _________________________________________________________________

# %%
# Assume you have stored the training history in the variable "history"
# Show the learning curves
pd.DataFrame(history.history).plot(figsize=(12, 8))
plt.gca().set_ylim(0, 1)
plt.grid(True)
plt.show()

# %% [markdown]
# ## Save the model

# %%
model.save('mnist.h5')

# %% [markdown]
# ## Load the model and evaluate it on the test data

# %%
model = keras.models.load_model("mnist.h5")
model.evaluate(X_test, y_test)
# Out:
# 313/313 [==============================] - 2s 5ms/step - loss: 0.0629 - accuracy: 0.9823
# [0.06292442977428436, 0.9822999835014343]

# %%
# %tensorboard --logdir logs
# Out:
# Reusing TensorBoard on port 6006 (pid 17076), started 17:49:01 ago. (Use '!kill 17076' to kill it.)
#       <iframe id="tensorboard-frame-83ced5a57d5e0afb" width="100%" height="800" frameborder="0">
#       </iframe>
#       <script>
#         (function() {
#           const frame = document.getElementById("tensorboard-frame-83ced5a57d5e0afb");
#           const url = new URL("/", window.location);
#           const port = 6006;
#           if (port) {
#             url.port = port;
#           }
#           frame.src = url;
#         })();
#       </script>

# %% [markdown]
# ## Short report
#
# Please write briefly how you build and train the model. Please include the decisions you made, such as why you use x number layers, and the difficulties you met.
